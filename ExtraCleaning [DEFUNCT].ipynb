# %%
data = pd.DataFrame(df["special_abilities"].value_counts())
# pd.set_option('display.max_rows', None)   // For showing all data forms
data
# Out:
#                                                     count
# special_abilities
# [{'name': 'Legendary Resistance', 'desc': 'If t...      9
# [{'name': 'Amphibious', 'desc': 'The dragon can...      8
# [{'name': 'Amphibious', 'desc': 'The dragon can...      8
# [{'name': 'Swarm', 'desc': "The swarm can occup...      4
# [{'name': "Devil's Sight", 'desc': "Magical dar...      4
# ...                                                   ...
# [{'name': 'Amphibious', 'desc': 'The toad can b...      1
# [{'name': 'Aberrant Ground', 'desc': 'The groun...      1
# [{'name': 'Innate Spellcasting', 'desc': "The g...      1
# [{'name': 'Brave', 'desc': 'The gladiator has a...      1
# [{'name': 'Ice Walk', 'desc': "The dragon can m...      1
#
# [223 rows x 1 columns]

# %%
df["special_abilities"] = df["special_abilities"].str.replace("[", '')
df["special_abilities"] = df["special_abilities"].str.replace("]", '')
df["special_abilities"] = df["special_abilities"].str.replace("{", '')
df["special_abilities"] = df["special_abilities"].str.replace("}", '')
df["special_abilities"] = df["special_abilities"].str.replace("',", ' ')
df["special_abilities"] = df["special_abilities"].str.replace("\"", '')
df["special_abilities"] = df["special_abilities"].str.replace("\\n", ' ')
df["special_abilities"] = df["special_abilities"].str.replace("url :", '')
df["special_abilities"] = df["special_abilities"].str.replace("'name': ", '')
df["special_abilities"] = df["special_abilities"].str.replace("'desc': ", '-- ')
df["special_abilities"] = df["special_abilities"].str.replace("'", '')
data = pd.DataFrame(df["special_abilities"].value_counts())
data
# Out:
#                                                     count
# special_abilities
# Legendary Resistance  -- If the dragon fails a ...      9
# Amphibious  -- The dragon can breathe air and w...      8
# Amphibious  -- The dragon can breathe air and w...      8
# Swarm  -- The swarm can occupy another creature...      4
# Devils Sight, -- Magical darkness doesnt impede...      4
# ...                                                   ...
# Amphibious  -- The toad can breathe air and wat...      1
# Aberrant Ground  -- The ground in a 10-foot rad...      1
# Innate Spellcasting  -- The glabrezus spellcast...      1
# Brave  -- The gladiator has advantage on saving...      1
# Ice Walk  -- The dragon can move across and cli...      1
#
# [223 rows x 1 columns]

# %%
data = pd.DataFrame(df["actions"].value_counts())
# pd.set_option('display.max_rows', None)   // For showing all data forms
data
# Out:
#                                                     count
# actions
# [{'name': 'Bites', 'desc': "Melee Weapon Attack...      4
# [{'name': 'Hooves', 'desc': 'Melee Weapon Attac...      3
# [{'name': 'Greataxe', 'desc': 'Melee Weapon Att...      2
# [{'name': 'Bite', 'desc': 'Melee Weapon Attack:...      2
# [{'name': 'Bite', 'desc': 'Melee Weapon Attack:...      2
# ...                                                   ...
# [{'name': 'Longsword', 'desc': 'Melee Weapon At...      1
# [{'name': 'Bite', 'desc': 'Melee Weapon Attack:...      1
# [{'name': 'Multiattack', 'desc': 'The golem mak...      1
# [{'name': 'Multiattack', 'desc': 'The giant mak...      1
# [{'name': 'Slam', 'desc': 'Melee Weapon Attack:...      1
#
# [309 rows x 1 columns]

# %%
df["actions"] = df["actions"].str.replace("[", '')
df["actions"] = df["actions"].str.replace("]", '')
df["actions"] = df["actions"].str.replace("}, ", ' | ')
df["actions"] = df["actions"].str.replace("{", '')
df["actions"] = df["actions"].str.replace("}", '')
df["actions"] = df["actions"].str.replace("',", ' ')
df["actions"] = df["actions"].str.replace("\"", '')
df["actions"] = df["actions"].str.replace("\\n", ' ')
df["actions"] = df["actions"].str.replace("url :", '')
df["actions"] = df["actions"].str.replace("'name': ", '')
df["actions"] = df["actions"].str.replace("'desc': ", '-- ')
df["actions"] = df["actions"].str.replace("'", '')
data = pd.DataFrame(df["actions"].value_counts())
data
# Out:
#                                                     count
# actions
# Bites  -- Melee Weapon Attack: +3 to hit, reach...      4
# Hooves  -- Melee Weapon Attack: +6 to hit, reac...      3
# Greataxe  -- Melee Weapon Attack: +6 to hit, re...      2
# Bite  -- Melee Weapon Attack: +0 to hit, reach ...      2
# Bite  -- Melee Weapon Attack: +1 to hit, reach ...      2
# ...                                                   ...
# Longsword  -- Melee Weapon Attack: +3 to hit, r...      1
# Bite  -- Melee Weapon Attack: +6 to hit, reach ...      1
# Multiattack  -- The golem makes two slam attack...      1
# Multiattack  -- The giant makes two greatsword ...      1
# Slam  -- Melee Weapon Attack: +3 to hit, reach ...      1
#
# [309 rows x 1 columns]

# %%
data = pd.DataFrame(df["legendary_actions"].value_counts())
# pd.set_option('display.max_rows', None)   // For showing all data forms
data
# Out:
#                                                     count
# legendary_actions
# [{'name': 'Detect', 'desc': 'The dragon makes a...      3
# [{'name': 'Detect', 'desc': 'The dragon makes a...      3
# [{'name': 'Detect', 'desc': 'The dragon makes a...      3
# [{'name': 'Detect', 'desc': 'The dragon makes a...      3
# [{'name': 'Detect', 'desc': 'The dragon makes a...      2
# [{'name': 'Detect', 'desc': 'The dragon makes a...      2
# [{'name': 'Claw Attack', 'desc': 'The sphinx ma...      2
# [{'name': 'Cantrip', 'desc': 'The lich casts a ...      1
# [{'name': 'Hooves', 'desc': 'The unicorn makes ...      1
# [{'name': 'Attack', 'desc': 'The tarrasque make...      1
# [{'name': 'Teleport', 'desc': 'The solar magica...      1
# [{'name': 'Attack', 'desc': 'The mummy lord mak...      1
# [{'name': 'Detect', 'desc': 'The aboleth makes ...      1
# [{'name': 'Tentacle Attack or Fling', 'desc': '...      1
# [{'name': 'Detect', 'desc': 'The dragon makes a...      1
# ...

# %%
df["legendary_actions"] = df["legendary_actions"].str.replace("[", '')
df["legendary_actions"] = df["legendary_actions"].str.replace("]", '')
df["legendary_actions"] = df["legendary_actions"].str.replace("}, {", ' | {')
df["legendary_actions"] = df["legendary_actions"].str.replace("{", '')
df["legendary_actions"] = df["legendary_actions"].str.replace("}", '')
df["legendary_actions"] = df["legendary_actions"].str.replace("',", ' ')
df["legendary_actions"] = df["legendary_actions"].str.replace("\"", '')
df["legendary_actions"] = df["legendary_actions"].str.replace("\\n", ' ')
df["legendary_actions"] = df["legendary_actions"].str.replace("url :", '')
df["legendary_actions"] = df["legendary_actions"].str.replace("'name': ", '')
df["legendary_actions"] = df["legendary_actions"].str.replace("'desc': ", '-- ')
df["legendary_actions"] = df["legendary_actions"].str.replace("'", '')
data = pd.DataFrame(df["legendary_actions"].value_counts())
data
# Out:
#                                                     count
# legendary_actions
# Detect  -- The dragon makes a Wisdom (Perceptio...      3
# Detect  -- The dragon makes a Wisdom (Perceptio...      3
# Detect  -- The dragon makes a Wisdom (Perceptio...      3
# Detect  -- The dragon makes a Wisdom (Perceptio...      3
# Detect  -- The dragon makes a Wisdom (Perceptio...      2
# Detect  -- The dragon makes a Wisdom (Perceptio...      2
# Claw Attack  -- The sphinx makes one claw attac...      2
# Cantrip  -- The lich casts a cantrip. | Paralyz...      1
# Hooves  -- The unicorn makes one attack with it...      1
# Attack  -- The tarrasque makes one claw attack ...      1
# Teleport  -- The solar magically teleports, alo...      1
# Attack  -- The mummy lord makes one attack with...      1
# Detect  -- The aboleth makes a Wisdom (Percepti...      1
# Tentacle Attack or Fling  -- The kraken makes o...      1
# Detect  -- The dragon makes a Wisdom (Perceptio...      1
# ...

# %%
data = pd.DataFrame(df["reactions"].value_counts())
# pd.set_option('display.max_rows', None)   // For showing all data forms
data
# Out:
#                                                     count
# reactions
# [{'name': 'Parry', 'desc': 'The captain adds 2 ...      1
# [{'name': 'Split', 'desc': "When a pudding that...      1
# [{'name': 'Unnerving Mask', 'desc': "When a cre...      1
# [{'name': 'Parry', 'desc': 'The erinyes adds 4 ...      1
# [{'name': 'Parry', 'desc': 'The gladiator adds ...      1
# [{'name': 'Parry', 'desc': 'The knight adds 2 t...      1
# [{'name': 'Parry', 'desc': 'The marilith adds 5...      1
# [{'name': 'Parry', 'desc': 'The noble adds 2 to...      1
# [{'name': 'Split', 'desc': "When a jelly that i...      1
# [{'name': 'Shield', 'desc': "When a creature ma...      1
# [{'name': 'Rock Catching', 'desc': 'If a rock o...      1

# %%
df["reactions"] = df["reactions"].str.replace("[", '')
df["reactions"] = df["reactions"].str.replace("]", '')
df["reactions"] = df["reactions"].str.replace("}, {", ' | {')
df["reactions"] = df["reactions"].str.replace("{", '')
df["reactions"] = df["reactions"].str.replace("}", '')
df["reactions"] = df["reactions"].str.replace("',", ' ')
df["reactions"] = df["reactions"].str.replace("\"", '')
df["reactions"] = df["reactions"].str.replace("\\n", ' ')
df["reactions"] = df["reactions"].str.replace("url :", '')
df["reactions"] = df["reactions"].str.replace("'name': ", '')
df["reactions"] = df["reactions"].str.replace("'desc': ", '-- ')
df["reactions"] = df["reactions"].str.replace("'", '')
data = pd.DataFrame(df["reactions"].value_counts())
data
# Out:
#                                                     count
# reactions
# Parry  -- The captain adds 2 to its AC against ...      1
# Split  -- When a pudding that is Medium or larg...      1
# Unnerving Mask  -- When a creature the devil ca...      1
# Parry  -- The erinyes adds 4 to its AC against ...      1
# Parry  -- The gladiator adds 3 to its AC agains...      1
# Parry  -- The knight adds 2 to its AC against o...      1
# Parry  -- The marilith adds 5 to its AC against...      1
# Parry  -- The noble adds 2 to its AC against on...      1
# Split  -- When a jelly that is Medium or larger...      1
# Shield  -- When a creature makes an attack agai...      1
# Rock Catching  -- If a rock or similar object i...      1
